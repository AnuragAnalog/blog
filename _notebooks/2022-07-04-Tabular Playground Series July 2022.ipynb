# %% [markdown]
# # Tabular Playground Series July 2022
#
# > "Cluster the TPS July 2022 data"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [kaggle, jupyter, tps, data, science, clustering]
# - hide: false

# %%
# Required modules

import tqdm
import numpy as np
import pandas as pd
import seaborn as sns

from zipfile import ZipFile
from matplotlib import pyplot as plt

from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation, MeanShift, SpectralClustering, AgglomerativeClustering, DBSCAN
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-bb29b059ff0b> in <module>()
#       9 from matplotlib import pyplot as plt
#      10
# ---> 11 from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation, MeanShift, SpectralClustering, AgglomerativeClustering, DBSCAN, BIRCH
#
# ImportError: cannot import name 'BIRCH' from 'sklearn.cluster' (/usr/local/lib/python3.7/dist-packages/sklearn/cluster/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Config

# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 12)

# %% [markdown]
# Before running the below cell, upload your kaggle token, to make sure an error doesn't popup.

# %%
# Create kaggle folder

# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Test the command

# !kaggle competitions download -c tabular-playground-series-jul-2022
# Out:
# ...
#  25% 5.00M/19.6M [00:00<00:00, 45.2MB/s]
# 100% 19.6M/19.6M [00:00<00:00, 99.7MB/s]

# %%
# Extract the zip file

with ZipFile('/content/tabular-playground-series-jul-2022.zip', 'r') as zf:
    zf.extractall('./')

# %% [markdown]
# ## Loading the data

# %%
# Load the data

data = pd.read_csv('data.csv', index_col='id')
data.head()
# Out:
#         f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# id
# 0  -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1  -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3  -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4  -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#     f_07  f_08  f_09  ...      f_19      f_20      f_21      f_22      f_23  \
# id                    ...
# 0      2    13    14  ... -0.478412 -0.757002 -0.763635 -1.090369  1.142641
# 1      2     3     6  ... -0.428791 -0.089908 -1.784204 -0.839474  0.459685
# 2      5    11     5  ... -0.413534 -1.602377  1.190984  3.267116 -0.088322
# 3      6     2    13  ...  0.619283  1.287801  0.532837  1.036631 -2.041828
# 4      8     7     5  ... -1.628830 -0.434948  0.322505  0.284326 -2.438365
#
# ...

# %%
# Inspecting the data

data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98000 entries, 0 to 97999
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   f_00    98000 non-null  float64
#  1   f_01    98000 non-null  float64
#  2   f_02    98000 non-null  float64
#  3   f_03    98000 non-null  float64
#  4   f_04    98000 non-null  float64
#  5   f_05    98000 non-null  float64
#  6   f_06    98000 non-null  float64
#  7   f_07    98000 non-null  int64
#  8   f_08    98000 non-null  int64
#  9   f_09    98000 non-null  int64
#  10  f_10    98000 non-null  int64
#  11  f_11    98000 non-null  int64
#  12  f_12    98000 non-null  int64
#  13  f_13    98000 non-null  int64
#  14  f_14    98000 non-null  float64
#  15  f_15    98000 non-null  float64
#  16  f_16    98000 non-null  float64
#  17  f_17    98000 non-null  float64
#  18  f_18    98000 non-null  float64
#  19  f_19    98000 non-null  float64
#  20  f_20    98000 non-null  float64
# ...

# %%
# Correlation matrix

sns.heatmap(data.corr(), annot=True, vmin=-1, vmax=1, cmap='RdYlGn')

# %% [markdown]
# Most of the features are not at all correlated with each other.

# %% [markdown]
# There are no missing values, in the data.

# %%
# Missing values

if data.isna().any().any():
    print(data.isna().sum()*100/data.shape[0])
else:
    print("No Missing values")
# Out:
# No Missing values

# %% [markdown]
# ## Try
#
# * Clustering with different algorithms(kmeans, dbscan)
# * Cluster with GMM
# * Repeat above with feature engineered data
# * After that apply PCA or Autoencoder and repeat
# * Visualize the results

# %% [markdown]
# ## K-Means Clustering

# %%
# Apply the Elbow method(KMeans)

wss = list()
n_clusters = range(1, 10)

for n in n_clusters:
    kmeans = KMeans(n_clusters=n)
    kmeans.fit(data)
    wss.append(kmeans.inertia_)

# %%
# Elbow Plot

plt.plot(n_clusters, wss)

# %% [markdown]
# From the above, elbow plot we can see that the change in the value of inertia is very less for the clusters 7, 8, 9.
#
# So I guess that the number of optimal clusters can be either 7 or 8.
#
# It is actually 7. because I tried 6 and 8 both gave very less rand index value.

# %%
# Fit with optimal clusters

kmeans = KMeans(n_clusters=7)
kmeans.fit(data)
kmeans_values = kmeans.predict(data)

# %% [markdown]
# ## Mini Batch K-Means Clustering

# %%
# Apply the Elbow method(MiniBatchKMeans)

wss = list()
n_clusters = range(1, 20)

for n in n_clusters:
    minikmeans = MiniBatchKMeans(n_clusters=n)
    minikmeans.fit(data)
    wss.append(minikmeans.inertia_)

# %%
# Elbow Plot

plt.plot(n_clusters, wss)

# %%
# Fit with optimal clusters

minikmeans = MiniBatchKMeans(n_clusters=7)
minikmeans.fit(data)
mini_values = minikmeans.predict(data)

# %% [markdown]
# ## Mean Shift Clustering

# %%
# Applying Meanshift clustering

ms = MeanShift(n_jobs=-1)
ms.fit(data)
# Out:
# MeanShift(n_jobs=-1)

# %%
# Predictions from mean shift

ms_values = ms.predict(data)

# %% [markdown]
# ## DBSCAN Clustering

# %%
# Appling DBSCAN

dbscan = DBSCAN(n_jobs=-1)
dbscan_values = dbscan.fit_predict(data)

# %% [markdown]
# ## Submission

# %%
# Making a copy

values = dbscan_values

# %%
# Filling the submission dataframe and Generating output file

submission = pd.read_csv('/content/sample_submission.csv')

submission['Predicted'] = values
submission.to_csv('output.csv', index=False)

# %%
# Submission

# !kaggle competitions submit -c tabular-playground-series-jul-2022 -f output.csv -m "Using DBSCAN"
# Out:
# 100% 850k/850k [00:01<00:00, 449kB/s]
# Successfully submitted to Tabular Playground Series - Jul 2022

# %% [markdown]
# Rand Index is: 0.23805
